# %% [markdown]
# Q1. Write a program that asks the user for their name and age, then prints a sentence like:
# Hello Shradha, you are 21 years old!

# %%
name = input("Enter a name:")
age = input("Enter age:")
print(f"Hello {name}, you are {age} years old!")
# Out:
# Enter a name: Shweta
# Enter age: 26
# Hello Shweta, you are 26 years old!

# %% [markdown]
# Q2.Take two numbers as input from the user and print their sum, difference, product, and quotient.

# %%
# Take input from user
a = int(input("Enter a number 1:"))
b = int(input("Enter a number 2:"))

# operations
print(a + b)
print(a - b)
print( a * b)
print( a / b)
# Out:
# Enter a number 1: 5
# Enter a number 2: 7
# 12
# -2
# 35
# 0.7142857142857143

# %% [markdown]
# Q3. Ask the user to enter two integers and one float. Convert them all to floats and print their average.

# %%
num1 = int(input(" Enter 1st integer:"))
num2 = int(input(" Enter 2nd integer:"))
num3 = float(input(" Enter 1st float:"))

avg = float((num1+num2+num3)/3)
print("Average of given numbers=", avg)
# Out:
#  Enter 1st integer: 7
#  Enter 2nd integer: 4
#  Enter 1st float: 8.5
# Average of given numbers= 6.5

# %% [markdown]
# Q4. The user enters a string containing a number (eg."45"). Convert it to integer, a float and
# a string again
# Print all three values with their types.

# %%
num1 = str(input("Enter a number:"))
print(type(num1))
a = int(num1)
print(type(a))
b = float(a)
print(type(b))
c = str(b)
print(type(c))
# Out:
# Enter a number: 45
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Q5. Evaluate and print the result of the following expression:
# x=10+3*2**2

# %%
x=10+3*2**2
print(x)
# Out:
# 22

# %% [markdown]
# Q6. Write a program to swap values of two numbers entered by the user.

# %%
a = int(input("Enter 1st number: "))
b = int(input("Enter 2nd number: "))

# Swapping
a, b = b, a

print("After swapping:")
print("a =", a, "b =", b)
# Out:
# Enter 1st number:  5
# Enter 2nd number:  7
# After swapping:
# a = 7 b = 5

# %% [markdown]
# Q7. Ask the user for a temperature in Celsius (string input). Convert it to float, then calculate and print temperature in Fahrenheit.

# %%
celsius = str(input("Enter Temprature:"))
Celsiustemp = float(celsius)
fahrenheittemp = (Celsiustemp * 9/5) + 32
print("Temprature in Fahrenheit=",fahrenheittemp)
# Out:
# Enter Temprature: 40
# Temprature in Fahrenheit= 104.0

# %% [markdown]
# Q8. Take the radius (r) as user input and print the area.

# %%
r = int(input("Enter the radius of the circle:"))
π = 3.14
Area = π * (r*r)
print("Area of circle is:", Area)
# Out:
# Enter the radius of the circle: 7
# Area of circle is: 153.86

# %% [markdown]
# Q9. Ask the user for: Principal (P), Rate (R), Time (T). Convert all to float and compute simple interest:

# %%
principal = int(input("Enter principal:"))
Rate = int(input("Enter rate:"))
Time = int(input("Enter time:"))
P = float(principal)
R = float(Rate)
T = float(Time)
SI = (P * R * T )/100
print(type(SI))
print("The simple Interest is = ", SI)
# Out:
# Enter principal: 5000
# Enter rate: 8
# Enter time: 4
# <class 'float'>
# The simple Interest is =  1600.0

# %% [markdown]
# Q10. Take a decimal number as input (like 45.78) and output its:
# integer part - 45, fractional part -.78

# %%
# Take decimal number input
num = float(input("Enter a decimal number: "))

# Integer part
integer_part = int(num)

# Fractional part
fractional_part = num - integer_part

# Display results
print("Integer part =", integer_part)
print("Fractional part =", fractional_part)
# Out:
# Enter a decimal number:  7.49
# Integer part = 7
# Fractional part = 0.4900000000000002
